# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
PS4csv = "PS4_GamesSales.csv"
PS4_data_df = pd.read_csv(PS4csv)

# %%
NewPS4_data_df = PS4_data_df[['Game', 'Year', 'Genre', 'Global']].copy()
NewPS4_data_df['Platform'] = "PS4"
RenamedPS4_data_df = NewPS4_data_df.rename(columns={'Game': 'game', 'Year':'year', 'Genre':'genre','Global':'ps4_global','Platform':'platform'})

# %%
Xboxcsv = "XboxOne_GameSales.csv"
Xbox_data_df = pd.read_csv(Xboxcsv)

# %%
NewXbox_data_df = Xbox_data_df[['Game', 'Year', 'Genre', 'Global']].copy()
NewXbox_data_df['Platform'] = "Xbox_One"
RenamedXbox_data_df = NewXbox_data_df.rename(columns={'Game': 'game', 'Year':'year', 'Genre':'genre','Global':'xbox_global', 'Platform':'platform'})

# %%
RenamedPS4_data_df.dropna(how='any', inplace = True)
RenamedPS4_data_df
# Out:
#                            game    year             genre  ps4_global platform
# 0            Grand Theft Auto V  2014.0            Action       19.39      PS4
# 1     Call of Duty: Black Ops 3  2015.0           Shooter       15.09      PS4
# 2         Red Dead Redemption 2  2018.0  Action-Adventure       13.94      PS4
# 3            Call of Duty: WWII  2017.0           Shooter       13.40      PS4
# 4                       FIFA 18  2017.0            Sports       11.80      PS4
# ...                         ...     ...               ...         ...      ...
# 1025                  Biomutant  2019.0            Action        0.00      PS4
# 1026                    de Blob  2017.0          Platform        0.00      PS4
# 1027           Chaos on Deponia  2017.0         Adventure        0.00      PS4
# 1028                  Code Vein  2018.0            Action        0.00      PS4
# 1030   Radial G Racing Revolved  2017.0            Racing        0.00      PS4
#
# [825 rows x 5 columns]

# %%
RenamedXbox_data_df.dropna(how='any', inplace = True)
RenamedXbox_data_df
# Out:
#                           game    year             genre  xbox_global  \
# 0           Grand Theft Auto V  2014.0            Action         8.72
# 1    Call of Duty: Black Ops 3  2015.0           Shooter         7.37
# 2           Call of Duty: WWII  2017.0           Shooter         6.23
# 3        Red Dead Redemption 2  2018.0  Action-Adventure         5.77
# 4                    MineCraft  2014.0              Misc         5.43
# ..                         ...     ...               ...          ...
# 608                  Biomutant  2018.0            Action         0.00
# 609                  Biomutant  2019.0            Action         0.00
# 610                    de Blob  2017.0          Platform         0.00
# 611    Outcast: Second Contact  2017.0         Adventure         0.00
# 612                  Code Vein  2019.0            Action         0.00
#
#      platform
# 0    Xbox_One
# 1    Xbox_One
# 2    Xbox_One
# 3    Xbox_One
# 4    Xbox_One
# ..        ...
# 608  Xbox_One
# ...

# %%
rds_connection_string = "admin1:12345@localhost:5432/ETLProject"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['ps4games', 'xboxgames']

# %%
RenamedPS4_data_df.to_sql(name='ps4games', con=engine, if_exists='append', index=False)

# %%
RenamedXbox_data_df.to_sql(name='xboxgames', con=engine, if_exists='append', index=False)
